# %% [markdown]
# # Nantes Social
# ## Etude des données sociales de l'agglomération Nantaise

# %% [markdown]
# L'open data de la ville de Nantes met toutes sortes de données libres et gratuites en ligne. J'ai choisi d'étudier son niveau social. Je commence donc par intégrer les données qui m'intéressent comme :
# - le nombre de bénéficiaires du RSA
# - Le nombre de bénéficiaires du FSL
# - Le nombre de travailleur sociaux
#
# A partir de ces données j'étudierais s'il y a un lien entre ces données et je verrais s'il est possible d'en tirer des conclusions.
# J'étudierais l'hypothèse que plus une ville a de bénéficiaire du RSA et + elle en a du FSL. J'essaierais de voir si + une commune a de bénéficiaire des minimas sociaux plus elle a de travailleurs sociaux. Si j'ai le temps je pousserais un peu plus loin pour voir les liens avec les données sur l'éducation.

# %% [markdown]
# Je commence par insérer mes différentes données à l'aide de la librairie Pandas

# %%
import pandas as pd
dfRSA = pd.read_csv('donnees/Beneficiaires_RSA_Commune.csv', header = 0)
dfFSL = pd.read_csv('donnees/Beneficiaires_FSL_Commune.csv', header = 0)
dfTS = pd.read_csv('donnees/Intervention_Travailleurs_Sociaux_Communes.csv', header = 0)

# %% [markdown]
# Commençons par observer les données

# %%
dfRSA.head(2)
# Out:
#                             location   Commune  Annee  \
# 0  [ 47.5559053978 , -1.49321993821]  ABBARETZ   2010
# 1  [ 47.5559053978 , -1.49321993821]  ABBARETZ   2015
#
#    Nombre de bénéficaires du RSA
# 0                           39.0
# 1                           43.0

# %%
dfFSL.head(2)
# Out:
#                             location   Commune  Annee  \
# 0  [ 47.5559053978 , -1.49321993821]  ABBARETZ   2010
# 1  [ 47.5559053978 , -1.49321993821]  ABBARETZ   2011
#
#    Nombre de bénéficaires de l'accompagnement FSL
# 0                                             NaN
# 1                                             NaN

# %%
dfTS.head(2)
# Out:
#                             location   Commune  Annee  \
# 0  [ 47.5559053978 , -1.49321993821]  ABBARETZ   2009
# 1  [ 47.5559053978 , -1.49321993821]  ABBARETZ   2010
#
#    Nombre de ménages ayant fait l'objet d'une intervention des travailleurs sociaux de CMS
# 0                                               67.0
# 1                                               64.0

# %% [markdown]
# Ces 3 débuts de tableaux indiquent la teneur de leurs données et nous indiquent leurs point communs à savoir :
# - une situation géographique
# - une commune
# - une année
# - un nombre portant sur les données souhaitées.
#
# Je commence par étudier la répartition par commune et par année.
# Pour me simplifier la tâche je vais renommer les dernières colonnes puis fusionner les tableaux.

# %%
dfRSA.columns =["location", "Commune","Annee","RSA"]
dfRSA.head(2)
# Out:
#                             location   Commune  Annee   RSA
# 0  [ 47.5559053978 , -1.49321993821]  ABBARETZ   2010  39.0
# 1  [ 47.5559053978 , -1.49321993821]  ABBARETZ   2015  43.0

# %%
dfFSL.columns =["location", "Commune","Annee","FSL"]
dfFSL.head(2)
# Out:
#                             location   Commune  Annee  FSL
# 0  [ 47.5559053978 , -1.49321993821]  ABBARETZ   2010  NaN
# 1  [ 47.5559053978 , -1.49321993821]  ABBARETZ   2011  NaN

# %% [markdown]
# On peut d'ores et déjà constater que certaines cellules ne sont pas remplies (NaN) ce qui laisse présager de problèmes à venir.

# %%
dfTS.columns = ["location", "Commune", "Annee","TS"]

# %% [markdown]
# Je leur donne un index pour les manipuler plus facilement.

# %%
dfRSAi = dfRSA.set_index(["Commune","Annee"])
dfFSLi = dfFSL.set_index(["Commune","Annee"])
dfTSi = dfTS.set_index(["Commune","Annee"])

# %% [markdown]
# Fusion des tableaux
# df_RSA_FSL = pd.concat([dfRSA, dfFSL])

# %%
# on a vu que le nombre de bénéficiaire du FSL était peu renseigné. On va tenter de faire un remplissage avec la médiane
# là c'est du grand n'importe quoi, quand on remplace une donnée par du null
for i in range(0, 2):
    median_fsl = dfFSLi.FSL.median()
    dfFSLi.loc[(dfFSLi.FSL.isnull()),'FSLFill'] = median_fsl

# %%
dfFSLi.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# MultiIndex: 1326 entries, (ABBARETZ, 2010) to (VUE, 2015)
# Data columns (total 3 columns):
# location    1326 non-null object
# FSL         728 non-null float64
# FSLFill     598 non-null float64
# dtypes: float64(2), object(1)
# memory usage: 41.4+ KB

# %%
dfFSLi.head(100)
# Out:
#                                                        location   FSL  FSLFill
# Commune                Annee
# ABBARETZ               2010   [ 47.5559053978 , -1.49321993821]   NaN      0.0
#                        2011   [ 47.5559053978 , -1.49321993821]   NaN      0.0
#                        2012   [ 47.5559053978 , -1.49321993821]   NaN      0.0
#                        2013   [ 47.5559053978 , -1.49321993821]   NaN      0.0
#                        2014   [ 47.5559053978 , -1.49321993821]   NaN      0.0
#                        2015   [ 47.5559053978 , -1.49321993821]   NaN      0.0
# AIGREFEUILLE-SUR-MAINE 2010    [ 47.071465819 , -1.41539314185]   0.0      NaN
#                        2011    [ 47.071465819 , -1.41539314185]   0.0      NaN
#                        2012    [ 47.071465819 , -1.41539314185]   0.0      NaN
#                        2013    [ 47.071465819 , -1.41539314185]   NaN      0.0
#                        2014    [ 47.071465819 , -1.41539314185]   NaN      0.0
#                        2015    [ 47.071465819 , -1.41539314185]   NaN      0.0
# ANCENIS                2010   [ 47.3834763632 , -1.18216539989]  14.0      NaN
#                        2011   [ 47.3834763632 , -1.18216539989]  18.0      NaN
#                        2012   [ 47.3834763632 , -1.18216539989]  15.0      NaN
#                        2013   [ 47.3834763632 , -1.18216539989]  15.0      NaN
#                        2014   [ 47.3834763632 , -1.18216539989]  26.0      NaN
#                        2015   [ 47.3834763632 , -1.18216539989]  23.0      NaN
# ANETZ                  2010   [ 47.3812469147 , -1.09404489844]   0.0      NaN
#                        2011   [ 47.3812469147 , -1.09404489844]   NaN      0.0
#                        2012   [ 47.3812469147 , -1.09404489844]   NaN      0.0
#                        2013   [ 47.3812469147 , -1.09404489844]   NaN      0.0
#                        2014   [ 47.3812469147 , -1.09404489844]   NaN      0.0
#                        2015   [ 47.3812469147 , -1.09404489844]   NaN      0.0
# ARTHON-EN-RETZ         2010   [ 47.1591412154 , -1.95348595036]   0.0      NaN
#                        2011   [ 47.1591412154 , -1.95348595036]   NaN      0.0
#                        2012   [ 47.1591412154 , -1.95348595036]   0.0      NaN
#                        2013   [ 47.1591412154 , -1.95348595036]   0.0      NaN
#                        2014   [ 47.1591412154 , -1.95348595036]   NaN      0.0
#                        2015   [ 47.1591412154 , -1.95348595036]   NaN      0.0
# ...                                                         ...   ...      ...
# BESNE                  2014    [ 47.3803275742 , -2.0746331445]   0.0      NaN
#                        2015    [ 47.3803275742 , -2.0746331445]   0.0      NaN
# BLAIN                  2010   [ 47.4631966796 , -1.76763546259]   NaN      0.0
#                        2011   [ 47.4631966796 , -1.76763546259]   8.0      NaN
#                        2012   [ 47.4631966796 , -1.76763546259]  10.0      NaN
#                        2013   [ 47.4631966796 , -1.76763546259]  13.0      NaN
#                        2014   [ 47.4631966796 , -1.76763546259]  14.0      NaN
#                        2015   [ 47.4631966796 , -1.76763546259]  12.0      NaN
# BONNOEUVRE             2010   [ 47.5201396948 , -1.23344255026]   0.0      NaN
#                        2011   [ 47.5201396948 , -1.23344255026]   0.0      NaN
#                        2012   [ 47.5201396948 , -1.23344255026]   0.0      NaN
#                        2013   [ 47.5201396948 , -1.23344255026]   0.0      NaN
#                        2014   [ 47.5201396948 , -1.23344255026]   NaN      0.0
#                        2015   [ 47.5201396948 , -1.23344255026]   NaN      0.0
# BOUAYE                 2010   [ 47.1475902945 , -1.67325732821]   0.0      NaN
#                        2011   [ 47.1475902945 , -1.67325732821]   NaN      0.0
#                        2012   [ 47.1475902945 , -1.67325732821]   5.0      NaN
#                        2013   [ 47.1475902945 , -1.67325732821]   NaN      0.0
#                        2014   [ 47.1475902945 , -1.67325732821]   7.0      NaN
#                        2015   [ 47.1475902945 , -1.67325732821]   7.0      NaN
# BOUEE                  2010   [ 47.3049306975 , -1.91286137429]   NaN      0.0
#                        2011   [ 47.3049306975 , -1.91286137429]   NaN      0.0
#                        2012   [ 47.3049306975 , -1.91286137429]   0.0      NaN
#                        2013   [ 47.3049306975 , -1.91286137429]   NaN      0.0
#                        2014   [ 47.3049306975 , -1.91286137429]   NaN      0.0
#                        2015   [ 47.3049306975 , -1.91286137429]   0.0      NaN
# BOUGUENAIS             2010   [ 47.1705880649 , -1.61688359971]  13.0      NaN
#                        2011   [ 47.1705880649 , -1.61688359971]  12.0      NaN
#                        2012   [ 47.1705880649 , -1.61688359971]  10.0      NaN
#                        2013   [ 47.1705880649 , -1.61688359971]  17.0      NaN
#
# [100 rows x 3 columns]

# %% [markdown]
# On peut donc constater l'erreur monumentale sur le traitement des données : Les cellules qui avaint des valeurs ont été remplacees par NaN !!!

# %%
# Observation de la correction effectuée sur 16 valeurs:
print dfFSLi [ dfFSLi['FSL'].isnull() ][['FSL','FSLFill']].head(10)
# Out:
#   File "<ipython-input-26-7cb56fd8f0fb>", line 3
#     print dfFSLi [ dfFSLi['FSL'].isnull() ][['FSL','FSLFill']].head(10)
#                ^
# SyntaxError: invalid syntax

# %%
# On peut maintenant vérifier que la colonne AgeFill ne contient plus de valeurs NaN:
print dfFSLi.loc[dfFSLi.FSLFill.isnull()]
# Out:
#   File "<ipython-input-23-042c487641b8>", line 2
#     print dfFSLi.loc[dfFSLi.FSLFill.isnull()]
#                ^
# SyntaxError: invalid syntax

# %%
df_Social = pd.concat([dfRSA, dfFSL, dfTS])
df_Social.head(500)
# Out:
#      Annee                    Commune  FSL    RSA  TS  \
# 0     2010                   ABBARETZ  NaN   39.0 NaN
# 1     2015                   ABBARETZ  NaN   43.0 NaN
# 2     2011                   ABBARETZ  NaN   43.0 NaN
# 3     2012                   ABBARETZ  NaN   41.0 NaN
# 4     2013                   ABBARETZ  NaN   38.0 NaN
# 5     2014                   ABBARETZ  NaN   41.0 NaN
# 6     2010     AIGREFEUILLE-SUR-MAINE  NaN   31.0 NaN
# 7     2015     AIGREFEUILLE-SUR-MAINE  NaN   38.0 NaN
# 8     2011     AIGREFEUILLE-SUR-MAINE  NaN   33.0 NaN
# 9     2012     AIGREFEUILLE-SUR-MAINE  NaN   33.0 NaN
# 10    2013     AIGREFEUILLE-SUR-MAINE  NaN   33.0 NaN
# 11    2014     AIGREFEUILLE-SUR-MAINE  NaN   35.0 NaN
# 12    2010                    ANCENIS  NaN  195.0 NaN
# 13    2015                    ANCENIS  NaN  278.0 NaN
# 14    2011                    ANCENIS  NaN  189.0 NaN
# 15    2012                    ANCENIS  NaN  215.0 NaN
# 16    2013                    ANCENIS  NaN  245.0 NaN
# 17    2014                    ANCENIS  NaN  264.0 NaN
# 18    2010                      ANETZ  NaN   21.0 NaN
# 19    2015                      ANETZ  NaN    NaN NaN
# 20    2011                      ANETZ  NaN   21.0 NaN
# 21    2012                      ANETZ  NaN   18.0 NaN
# 22    2013                      ANETZ  NaN   25.0 NaN
# 23    2014                      ANETZ  NaN   22.0 NaN
# 24    2010             ARTHON-EN-RETZ  NaN   43.0 NaN
# 25    2015             ARTHON-EN-RETZ  NaN  104.0 NaN
# 26    2011             ARTHON-EN-RETZ  NaN   30.0 NaN
# 27    2012             ARTHON-EN-RETZ  NaN   47.0 NaN
# 28    2013             ARTHON-EN-RETZ  NaN   56.0 NaN
# 29    2014             ARTHON-EN-RETZ  NaN   65.0 NaN
# ..     ...                        ...  ...    ...  ..
# 470   2010  LA MEILLERAYE-DE-BRETAGNE  NaN   20.0 NaN
# 471   2011  LA MEILLERAYE-DE-BRETAGNE  NaN   19.0 NaN
# 472   2012  LA MEILLERAYE-DE-BRETAGNE  NaN   24.0 NaN
# 473   2013  LA MEILLERAYE-DE-BRETAGNE  NaN   25.0 NaN
# 474   2014                LA MONTAGNE  NaN  130.0 NaN
# 475   2015                LA MONTAGNE  NaN  135.0 NaN
# 476   2010                LA MONTAGNE  NaN   87.0 NaN
# 477   2011                LA MONTAGNE  NaN  100.0 NaN
# 478   2012                LA MONTAGNE  NaN  106.0 NaN
# 479   2013                LA MONTAGNE  NaN  104.0 NaN
# 480   2014          LA PLAINE-SUR-MER  NaN   73.0 NaN
# 481   2015          LA PLAINE-SUR-MER  NaN   79.0 NaN
# 482   2010          LA PLAINE-SUR-MER  NaN   56.0 NaN
# 483   2011          LA PLAINE-SUR-MER  NaN   61.0 NaN
# 484   2012          LA PLAINE-SUR-MER  NaN   69.0 NaN
# 485   2013          LA PLAINE-SUR-MER  NaN   71.0 NaN
# 486   2014                 LA PLANCHE  NaN   31.0 NaN
# 487   2015                 LA PLANCHE  NaN   35.0 NaN
# 488   2010                 LA PLANCHE  NaN   33.0 NaN
# 489   2011                 LA PLANCHE  NaN   24.0 NaN
# 490   2012                 LA PLANCHE  NaN   28.0 NaN
# 491   2013                 LA PLANCHE  NaN   34.0 NaN
# 492   2014             LA REGRIPPIERE  NaN   19.0 NaN
# 493   2015             LA REGRIPPIERE  NaN   13.0 NaN
# 494   2010             LA REGRIPPIERE  NaN   17.0 NaN
# 495   2011             LA REGRIPPIERE  NaN   15.0 NaN
# 496   2012             LA REGRIPPIERE  NaN   11.0 NaN
# 497   2013             LA REGRIPPIERE  NaN   19.0 NaN
# 498   2014              LA REMAUDIERE  NaN   14.0 NaN
# 499   2015              LA REMAUDIERE  NaN   17.0 NaN
#
#                               location
# 0    [ 47.5559053978 , -1.49321993821]
# 1    [ 47.5559053978 , -1.49321993821]
# 2    [ 47.5559053978 , -1.49321993821]
# 3    [ 47.5559053978 , -1.49321993821]
# 4    [ 47.5559053978 , -1.49321993821]
# 5    [ 47.5559053978 , -1.49321993821]
# 6     [ 47.071465819 , -1.41539314185]
# 7     [ 47.071465819 , -1.41539314185]
# 8     [ 47.071465819 , -1.41539314185]
# 9     [ 47.071465819 , -1.41539314185]
# 10    [ 47.071465819 , -1.41539314185]
# 11    [ 47.071465819 , -1.41539314185]
# 12   [ 47.3834763632 , -1.18216539989]
# 13   [ 47.3834763632 , -1.18216539989]
# 14   [ 47.3834763632 , -1.18216539989]
# 15   [ 47.3834763632 , -1.18216539989]
# 16   [ 47.3834763632 , -1.18216539989]
# 17   [ 47.3834763632 , -1.18216539989]
# 18   [ 47.3812469147 , -1.09404489844]
# 19   [ 47.3812469147 , -1.09404489844]
# 20   [ 47.3812469147 , -1.09404489844]
# 21   [ 47.3812469147 , -1.09404489844]
# 22   [ 47.3812469147 , -1.09404489844]
# 23   [ 47.3812469147 , -1.09404489844]
# 24   [ 47.1591412154 , -1.95348595036]
# 25   [ 47.1591412154 , -1.95348595036]
# 26   [ 47.1591412154 , -1.95348595036]
# 27   [ 47.1591412154 , -1.95348595036]
# 28   [ 47.1591412154 , -1.95348595036]
# 29   [ 47.1591412154 , -1.95348595036]
# ..                                 ...
# 470  [ 47.5637683188 , -1.39409586556]
# 471  [ 47.5637683188 , -1.39409586556]
# 472  [ 47.5637683188 , -1.39409586556]
# 473  [ 47.5637683188 , -1.39409586556]
# 474  [ 47.1848413335 , -1.68406936038]
# 475  [ 47.1848413335 , -1.68406936038]
# 476  [ 47.1848413335 , -1.68406936038]
# 477  [ 47.1848413335 , -1.68406936038]
# 478  [ 47.1848413335 , -1.68406936038]
# 479  [ 47.1848413335 , -1.68406936038]
# 480  [ 47.1444672101 , -2.18444710256]
# 481  [ 47.1444672101 , -2.18444710256]
# 482  [ 47.1444672101 , -2.18444710256]
# 483  [ 47.1444672101 , -2.18444710256]
# 484  [ 47.1444672101 , -2.18444710256]
# 485  [ 47.1444672101 , -2.18444710256]
# 486  [ 47.0201645485 , -1.44015299954]
# 487  [ 47.0201645485 , -1.44015299954]
# 488  [ 47.0201645485 , -1.44015299954]
# 489  [ 47.0201645485 , -1.44015299954]
# 490  [ 47.0201645485 , -1.44015299954]
# 491  [ 47.0201645485 , -1.44015299954]
# 492  [ 47.1849657405 , -1.19429776816]
# 493  [ 47.1849657405 , -1.19429776816]
# 494  [ 47.1849657405 , -1.19429776816]
# 495  [ 47.1849657405 , -1.19429776816]
# 496  [ 47.1849657405 , -1.19429776816]
# 497  [ 47.1849657405 , -1.19429776816]
# 498  [ 47.2268098433 , -1.23235940831]
# 499  [ 47.2268098433 , -1.23235940831]
#
# [500 rows x 6 columns]

# %% [markdown]
# là il y a clairement un problème. Il faut remplir les colonnes vides avant de fusionner les tableaux !

# %% [markdown]
# je vais donc calculer la médiane par commune et remplir les données non renseignées par cette donnée.
# dFslV = dfFSL.groupby("Commune")

# %%
import numpy as np
dfFSLiV = dfFSLi.groupby("Commune")
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# E:\Anaconda\lib\site-packages\pandas\indexes\base.py in get_loc(self, key, method, tolerance)
#    1944             try:
# -> 1945                 return self._engine.get_loc(key)
#    1946             except KeyError:
#
# pandas\index.pyx in pandas.index.IndexEngine.get_loc (pandas\index.c:4154)()
#
# pandas\index.pyx in pandas.index.IndexEngine.get_loc (pandas\index.c:4018)()
#
# pandas\hashtable.pyx in pandas.hashtable.PyObjectHashTable.get_item (pandas\hashtable.c:12368)()
#
# pandas\hashtable.pyx in pandas.hashtable.PyObjectHashTable.get_item (pandas\hashtable.c:12322)()
#
# KeyError: 'Commune'
#
# During handling of the above exception, another exception occurred:
#
# KeyError                                  Traceback (most recent call last)
# <ipython-input-14-6779fa246cb8> in <module>()
#       1 import numpy as np
# ----> 2 dfFSLiV = dfFSLi.groupby("Commune")
#
# E:\Anaconda\lib\site-packages\pandas\core\generic.py in groupby(self, by, axis, level, as_index, sort, group_keys, squeeze, **kwargs)
#    3776         return groupby(self, by=by, axis=axis, level=level, as_index=as_index,
#    3777                        sort=sort, group_keys=group_keys, squeeze=squeeze,
# -> 3778                        **kwargs)
#    3779
#    3780     def asfreq(self, freq, method=None, how=None, normalize=False):
#
# E:\Anaconda\lib\site-packages\pandas\core\groupby.py in groupby(obj, by, **kwds)
#    1425         raise TypeError('invalid type: %s' % type(obj))
#    1426
# -> 1427     return klass(obj, by, **kwds)
#    1428
#    1429
#
# E:\Anaconda\lib\site-packages\pandas\core\groupby.py in __init__(self, obj, keys, axis, level, grouper, exclusions, selection, as_index, sort, group_keys, squeeze, **kwargs)
#     352                                                     level=level,
#     353                                                     sort=sort,
# --> 354                                                     mutated=self.mutated)
#     355
#     356         self.obj = obj
#
# E:\Anaconda\lib\site-packages\pandas\core\groupby.py in _get_grouper(obj, key, axis, level, sort, mutated)
#    2381
#    2382         elif is_in_axis(gpr):  # df.groupby('name')
# -> 2383             in_axis, name, gpr = True, gpr, obj[gpr]
#    2384             exclusions.append(name)
#    2385
#
# E:\Anaconda\lib\site-packages\pandas\core\frame.py in __getitem__(self, key)
#    1995             return self._getitem_multilevel(key)
#    1996         else:
# -> 1997             return self._getitem_column(key)
#    1998
#    1999     def _getitem_column(self, key):
#
# E:\Anaconda\lib\site-packages\pandas\core\frame.py in _getitem_column(self, key)
#    2002         # get column
#    2003         if self.columns.is_unique:
# -> 2004             return self._get_item_cache(key)
#    2005
#    2006         # duplicate columns & possible reduce dimensionality
#
# E:\Anaconda\lib\site-packages\pandas\core\generic.py in _get_item_cache(self, item)
#    1348         res = cache.get(item)
#    1349         if res is None:
# -> 1350             values = self._data.get(item)
#    1351             res = self._box_item_values(item, values)
#    1352             cache[item] = res
#
# E:\Anaconda\lib\site-packages\pandas\core\internals.py in get(self, item, fastpath)
#    3288
#    3289             if not isnull(item):
# -> 3290                 loc = self.items.get_loc(item)
#    3291             else:
#    3292                 indexer = np.arange(len(self.items))[isnull(self.items)]
#
# E:\Anaconda\lib\site-packages\pandas\indexes\base.py in get_loc(self, key, method, tolerance)
#    1945                 return self._engine.get_loc(key)
#    1946             except KeyError:
# -> 1947                 return self._engine.get_loc(self._maybe_cast_indexer(key))
#    1948
#    1949         indexer = self.get_indexer([key], method=method, tolerance=tolerance)
#
# pandas\index.pyx in pandas.index.IndexEngine.get_loc (pandas\index.c:4154)()
#
# pandas\index.pyx in pandas.index.IndexEngine.get_loc (pandas\index.c:4018)()
#
# pandas\hashtable.pyx in pandas.hashtable.PyObjectHashTable.get_item (pandas\hashtable.c:12368)()
#
# pandas\hashtable.pyx in pandas.hashtable.PyObjectHashTable.get_item (pandas\hashtable.c:12322)()
#
# KeyError: 'Commune'
